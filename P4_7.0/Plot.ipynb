# %%
import numpy as np
import matplotlib.pyplot as plt


def plot(x, y1, y2, x_name, y_name, curve1_name, curve2_name, fig_name):
    plt.figure(figsize=(8, 5))
    plt.rcParams.update({'font.size':11})
    plt.plot(x, y2, color="C0", label=curve2_name, linewidth=1.5)
    plt.plot(x, y1, color="C1", label=curve1_name, linewidth=1.5)
    plt.xlabel(x_name)
    plt.ylabel(y_name)
    plt.title(fig_name)
    plt.legend()
    plt.show()

# Task 4:
print("\n\n---------------------- Task 4: ----------------------")

# 1ns:
t = range(1,102)
# Forward Euler:
data = np.genfromtxt('/Users/heyuan/eclipse-workspace/ECE4960-P4/forwardEulerCircuit1_1ns.txt', delimiter='\t')  
V1, V2 = data[:, 0], data[:,1]
plot(t, V1, V2, "t (ns)", "Voltage (V)", "V1", "V2", "Forward Euler (1ns)")
# RK4:
data = np.genfromtxt('/Users/heyuan/eclipse-workspace/ECE4960-P4/RK4Circuit1_1ns.txt', delimiter='\t')  
V1, V2 = data[:, 0], data[:,1]
plot(t, V1, V2, "t (ns)", "Voltage (V)", "V1", "V2", "RK4 (1ns)")
# RK34 with time adaption:
data = np.genfromtxt('/Users/heyuan/eclipse-workspace/ECE4960-P4/RK34Circuit1_1ns.txt', delimiter='\t')  
V1, V2 = data[:, 0], data[:,1]
plot(t, V1, V2, "t (ns)", "Voltage (V)", "V1", "V2", "RK34 with time adaption (1ns)")


# 0.2ns:
t = np.arange(0.0, 100.0, 0.2)
# Forward Euler:
data = np.genfromtxt('/Users/heyuan/eclipse-workspace/ECE4960-P4/forwardEulerCircuit1_02ns.txt', delimiter='\t')  
V1, V2 = data[:, 0], data[:,1]
plot(t, V1, V2, "t (ns)", "Voltage (V)", "V1", "V2", "Forward Euler (0.2ns)")
# RK4:
data = np.genfromtxt('/Users/heyuan/eclipse-workspace/ECE4960-P4/RK4Circuit1_02ns.txt', delimiter='\t')  
V1, V2 = data[:, 0], data[:,1]
plot(t, V1, V2, "t (ns)", "Voltage (V)", "V1", "V2", "RK4 (0.2ns)")
# RK34 with time adaption:
data = np.genfromtxt('/Users/heyuan/eclipse-workspace/ECE4960-P4/RK34Circuit1_02ns.txt', delimiter='\t')  
V1, V2 = data[:, 0], data[:,1]
plot(t, V1, V2, "t (ns)", "Voltage (V)", "V1", "V2", "RK34 with time adaption (0.2ns)")


# Task 5:
print("\n\n---------------------- Task 5: ----------------------")

t = range(1,102)
# Forward Euler:
data = np.genfromtxt('/Users/heyuan/eclipse-workspace/ECE4960-P4/forwardEulerCircuit2_1ns.txt', delimiter='\t')  
V1, V2 = data[:, 0], data[:,1]
plot(t, V1, V2, "t (ns)", "Voltage (V)", "V1", "V2", "Forward Euler (1ns)")
# RK4:
data = np.genfromtxt('/Users/heyuan/eclipse-workspace/ECE4960-P4/RK4Circuit2_1ns.txt', delimiter='\t')  
V1, V2 = data[:, 0], data[:,1]
plot(t, V1, V2, "t (ns)", "Voltage (V)", "V1", "V2", "RK4 (1ns)")
# RK34 with time adaption:
data = np.genfromtxt('/Users/heyuan/eclipse-workspace/ECE4960-P4/RK34Circuit2_1ns.txt', delimiter='\t')  
V1, V2 = data[:, 0], data[:,1]
plot(t, V1, V2, "t (ns)", "Voltage (V)", "V1", "V2", "RK34 with time adaption (1ns)")


# 0.2ns:
t = np.arange(0.0, 100.0, 0.2)
# Forward Euler:
data = np.genfromtxt('/Users/heyuan/eclipse-workspace/ECE4960-P4/forwardEulerCircuit2_02ns.txt', delimiter='\t')  
V1, V2 = data[:, 0], data[:,1]
plot(t, V1, V2, "t (ns)", "Voltage (V)", "V1", "V2", "Forward Euler (0.2ns)")
# RK4:
data = np.genfromtxt('/Users/heyuan/eclipse-workspace/ECE4960-P4/RK4Circuit2_02ns.txt', delimiter='\t')  
V1, V2 = data[:, 0], data[:,1]
plot(t, V1, V2, "t (ns)", "Voltage (V)", "V1", "V2", "RK4 (0.2ns)")
# RK34 with time adaption:
data = np.genfromtxt('/Users/heyuan/eclipse-workspace/ECE4960-P4/RK34Circuit2_02ns.txt', delimiter='\t')  
V1, V2 = data[:, 0], data[:,1]
plot(t, V1, V2, "t (ns)", "Voltage (V)", "V1", "V2", "RK34 with time adaption (0.2ns)")
# Out:
# ---------------------- Task 4: ----------------------
# ---------------------- Task 5: ----------------------
